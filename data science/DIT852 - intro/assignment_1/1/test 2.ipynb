# %%
import pandas as pd
import matplotlib.pyplot as plt
import csv

# %%
data = pd.read_csv("life-expectancy.csv")
GDP = pd.read_csv('gdp-world-regions-stacked-area.csv')
data.plot()
GDP.plot()
"""
https://ourworldindata.org/life-expectancy
"""
# Out:
# '\nhttps://ourworldindata.org/life-expectancy\n'

# %%
x = []
y = []

for i in range(len(data['Year'])):
    if data['Year'][i] == 2018:
        y.append(data['Life expectancy'][i])
        
for i in range(len(GDP['Year'])):
    if GDP['Year'][i] == 2018:
        x.append(GDP['GDP'][i])

pd
print(len(x), len(y))
        
plt.title('Life expectancy ', fontsize=15)
#plt.ylabel("Age")
#plt.xlabel("Year")

plt.xticks(rotation = 25)
plt.scatter(x,y)
#plt.scatter(x[start:end],y[start:end])
# Out:
# 3 3
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-61-3c8d54172b27> in <module>
#      25
#      26 plt.xticks(rotation = 25)
# ---> 27 plt.scatter(X,Y)
#      28 #plt.scatter(x[start:end],y[start:end])
#
# c:\python\3.9.0\lib\site-packages\matplotlib\pyplot.py in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, plotnonfinite, data, **kwargs)
#    2888         verts=cbook.deprecation._deprecated_parameter,
#    2889         edgecolors=None, *, plotnonfinite=False, data=None, **kwargs):
# -> 2890     __ret = gca().scatter(
#    2891         x, y, s=s, c=c, marker=marker, cmap=cmap, norm=norm,
#    2892         vmin=vmin, vmax=vmax, alpha=alpha, linewidths=linewidths,
#
# c:\python\3.9.0\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1436     def inner(ax, *args, data=None, **kwargs):
# ...
